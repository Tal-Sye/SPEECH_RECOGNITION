# %% [markdown]
# <a href="https://colab.research.google.com/github/Tal-Sye/SPEECH_RECOGNITION/blob/main/whisper_tiny.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Change Runtime to GPU T4
# !pip install openai-whisper

# %%
import torch
import whisper
from IPython.display import Audio, display

# Check if CUDA is available for GPU usage
use_cuda = torch.cuda.is_available()
device = "cuda" if use_cuda else "cpu"

# Load the Whisper model (large version)
model = whisper.load_model("tiny", device=device)

#CAN REPLACE LARGE WITH TINY, SMALL, MEDIUM

# %%
# Path to the audio file you want to transcribe
audio_path = "/content/DATA.mp3"  # Replace with your actual file path

# Play the audio
# display(Audio(audio_path, autoplay=True)) # Set autoplay=True to play automatically

# Transcribe the audio to text
result = model.transcribe(audio_path)

# Output the transcription
print(result["text"])
# Out:
#  In theory, the reason is the policy of an empire and an empire is a nation to pose a different reasons, living under the varying forms of government. A republic cannot be an empire. A power is a public rest of the theory that governments desire their trust powers from the consent of the government and colonialism finally distilled. We do not want the Filipino forces to exist. They cannot without danger to us, share in the government of our nation. And for over, we cannot afford to have another rich question for the rich question for the already-haves. Neither can we hold a Filipino's acceptance, even if we could benefit 10 by so-to-ish, for a second inconsistency, would paralyze our influence as the worst feature in the science of government. Our extremity-colonialism has been unfortunately, instead of partitive as drop-long, instead of strengthening as drop-eachness, instead of growing and obstructing the leadership, you have more than doubled our standing armament, and there is ta
# ...
